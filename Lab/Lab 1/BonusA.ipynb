# %%
import pandas as pd
olympicYears = [2000,2004,2008,2012,2016]
olympicData = [2000,2004,2008,2012,2016]
medalTable = [2000,2004,2008,2012,2016]
top20 = [2000,2004,2008,2012,2016]

olympicData[0] = pd.read_html("https://en.wikipedia.org/wiki/2000_Summer_Olympics_medal_table")
olympicData[1] = pd.read_html("https://en.wikipedia.org/wiki/2004_Summer_Olympics_medal_table")
olympicData[2] = pd.read_html("https://en.wikipedia.org/wiki/2008_Summer_Olympics_medal_table")
olympicData[3] = pd.read_html("https://en.wikipedia.org/wiki/2012_Summer_Olympics_medal_table")
olympicData[4] = pd.read_html("https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table")



for i in range(len(medalTable)) :
    medalTable[i] = olympicData[i][2]
    print(olympicYears[i])
    #print(medalTable[i])
    medalTable20 = medalTable[i]
    top20[i] = medalTable20.iloc[0:20,1:]
    print(top20[i])
    print("")
# Out:
# 2000
#            Nation  Gold  Silver  Bronze  Total
# 0   United States    37      24      32     93
# 1          Russia    32      28      29     89
# 2           China    28      16      14     58
# 3      Australia*    16      25      17     58
# 4         Germany    13      17      26     56
# 5          France    13      14      11     38
# 6           Italy    13       8      13     34
# 7     Netherlands    12       9       4     25
# 8            Cuba    11      11       7     29
# 9   Great Britain    11      10       7     28
# 10        Romania    11       6       9     26
# 11    South Korea     8      10      10     28
# 12        Hungary     8       6       3     17
# 13         Poland     6       5       3     14
# 14          Japan     5       8       5     18
# 15       Bulgaria     5       6       2     13
# 16         Greece     4       6       3     13
# 17         Sweden     4       5       3     12
# 18         Norway     4       3       3     10
# ...
