# %%
import pandas as pd
trainData = pd.read_csv('train.csv', header = None)
trainData.head()
print("Data type:", trainData.dtypes)
print("")
print("Data dims:", trainData.shape)
print("")
print("Data info:", trainData.info)
print("")
print("Data info:", trainData.describe)
# Out:
# Data type: 0     object
# 1     object
# 2     object
# 3     object
# 4     object
#        ...
# 76    object
# 77    object
# 78    object
# 79    object
# 80    object
# Length: 81, dtype: object
#
# Data dims: (1461, 81)
#
# Data info: <bound method DataFrame.info of         0           1         2            3        4       5      6   \
# 0       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley
# 1        1          60        RL           65     8450    Pave    NaN
# 2        2          20        RL           80     9600    Pave    NaN
# 3        3          60        RL           68    11250    Pave    NaN
# 4        4          70        RL           60     9550    Pave    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1456  1456          60        RL           62     7917    Pave    NaN
# 1457  1457          20        RL           85    13175    Pave    NaN
# 1458  1458          70        RL           66     9042    Pave    NaN
# ...
